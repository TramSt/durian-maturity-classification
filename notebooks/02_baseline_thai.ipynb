# %% [markdown]
# <a href="https://colab.research.google.com/github/TramSt/durian-maturity-classification/blob/main/notebooks/02_baseline_thai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===== CELL 1: Chạy đầu tiên mỗi session =====
from google.colab import drive
drive.mount('/content/drive')

# Đường dẫn gốc (dùng lại ở mọi notebook)
BASE = '/content/drive/MyDrive/DurianProject'
DATA = f'{BASE}/datasets'
MODELS = f'{BASE}/models'
RESULTS = f'{BASE}/results'

# Cài thư viện cần thiết
# !pip install timm albumentations grad-cam -q

print("✓ Drive mounted")
print("✓ Libraries installed")
# Out:
# Mounted at /content/drive
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 61.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# ✓ Drive mounted
# ✓ Libraries installed
